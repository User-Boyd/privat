# %%
import pandas as pd
import requests
import xml.etree.ElementTree as ET
import xml.dom.minidom
import json
import csv
import datetime as dt

# %%
myToken = 'NLOD'
myUrl = 'https://api.entur.io/realtime/v1/rest/et?datasetId=FLT'
head = {'Authorization': 'token {}'.format(myToken)}
response = requests.get(myUrl, headers=head)
# Print raw text content of the response to check the format, this is how I found out that it´s xml
#print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><Siri xmlns="http://www.siri.org.uk/siri" xmlns:ns2="http://www.ifopt.org.uk/acsb" xmlns:ns3="http://www.ifopt.org.uk/ifopt" xmlns:ns4="http://datex2.eu/schema/2_0RC1/2_0" version="2.0"><ServiceDelivery><ResponseTimestamp>2024-10-21T21:13:13.055691831+02:00</ResponseTimestamp><ProducerRef>ENT</ProducerRef><EstimatedTimetableDelivery version="2.0"><ResponseTimestamp>2024-10-21T21:13:13.055693468+02:00</ResponseTimestamp><EstimatedJourneyVersionFrame><RecordedAtTime>2024-10-21T21:13:13.05569244+02:00</RecordedAtTime><EstimatedVehicleJourney><RecordedAtTime>2024-10-21T18:11:13.890534162+02:00</RecordedAtTime><LineRef>FLT:Line:FLY1</LineRef><DirectionRef>ToDrammen</DirectionRef><FramedVehicleJourneyRef><DataFrameRef>2024-10-22</DataFrameRef><DatedVehicleJourneyRef>FLT:ServiceJourney:1-2614-3754-20241022</DatedVehicleJourneyRef></FramedVehicleJourneyRef><VehicleMode>rail</VehicleMode><OriginRef>GAR</OriginRef><DestinationRef>DRM</DestinationRef><OperatorRef>FLT:Operator:507</OperatorRef><ProductCategoryRef>Flytoget</ProductCategoryRef><ServiceFeatureRef>Unknown</ServiceFeatureRef><Monitored>true</Monitored><DataSource>FLT</DataSource><VehicleRef>3754</VehicleRef><EstimatedCalls><EstimatedCall><StopPointRef>NSR:Quay:453</StopPointRef><Order>1</Order><StopPointName>Gardermoen</StopPointName><ArrivalStatus>arrived</ArrivalStatus><ArrivalPlatformName>3</ArrivalPlatformName><ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity><AimedDepartureTime>2024-10-22T14:10:00+02:00</AimedDepartureTime><ExpectedDepartureTime>2024-10-22T14:10:00+02:00</ExpectedDepartureTime><DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName><DepartureBoardingActivity>boarding</DepartureBoardingActivity></EstimatedCall><EstimatedCall><StopPointRef>NSR:Quay:755</StopPointRef><Order>2</Order><StopPointName>Lillestr\xc3\xb8m</StopPointName><AimedArrivalTime>2024-10-22T14:21:30+02:00</AimedArrivalTime><ExpectedArrivalTime>2024-10-22T14:21:30+02:00</ExpectedArrivalTime><ArrivalStatus>arrived</ArrivalStatus><ArrivalPlatformName>2</ArrivalPlatformName><ArrivalBoardingActivity>alighting</ArrivalBoardingActivity><AimedDepartureTime>2024-10-22T14:22:00+02:00</AimedDepartureTime><ExpectedDepartureTime>2024-10-22T14:22:00+02:00</ExpectedDepartureTime><DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName><DepartureBoardingActivity>noBoarding</DepartureBoardingActivity></EstimatedCall><EstimatedCall><StopPointRef>NSR:Quay:570</StopPointRef><Order>3</Order><StopPointName>Oslo S</StopPointName><AimedArrivalTime>2024-10-22T14:32:00+02:00</AimedArrivalTime><ExpectedArrivalTime>2024-10-22T14:32:00+02:00</ExpectedArrivalTime><ArrivalStatus>arrived</ArrivalStatus><ArrivalPlatformName>2</ArrivalPlatformName><ArrivalBoardingActivity>alighting</ArrivalBoardingActivity><AimedDepartureTime>2024-10-22T14:35:00+02:00</AimedDepartureTime><ExpectedDepartureTime>2024-10-22T14:35:00+02:00</ExpectedDepartureTime><DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName><DepartureBoardingActivity>noBoarding</DepartureBoardingActivity></EstimatedCall><EstimatedCall><StopPointRef>NSR:Quay:475</StopPointRef><Order>4</Order><StopPointName>Nationaltheatret</StopPointName><AimedArrivalTime>2024-10-22T14:36:10+02:00</AimedArrivalTime><ExpectedArrivalTime>2024-10-22T14:36:10+02:00</ExpectedArrivalTime><ArrivalStatus>arrived</ArrivalStatus><ArrivalPlatformName>1</ArrivalPlatformName><ArrivalBoardingActivity>alighting</ArrivalBoardingActivity><AimedDepartureTime>2024-10-22T14:37:00+02:00</AimedDepartureTime><ExpectedDepartureTime>2024-10-22T14:37:00+02:00</ExpectedDepartureTime><DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">1</DeparturePlatfo ...

# %%
# Parse the raw XML content
xml_string = response.content

# Parse the original, unformatted XML string
tree = ET.ElementTree(ET.fromstring(xml_string))
root = tree.getroot()

# Pretty print for viewing:
dom = xml.dom.minidom.parseString(xml_string)
pretty_xml_as_string = dom.toprettyxml()
#print(pretty_xml_as_string)  # Looking at the xml format
# Out:
# <?xml version="1.0" ?>
# <Siri xmlns="http://www.siri.org.uk/siri" xmlns:ns2="http://www.ifopt.org.uk/acsb" xmlns:ns3="http://www.ifopt.org.uk/ifopt" xmlns:ns4="http://datex2.eu/schema/2_0RC1/2_0" version="2.0">
# 	<ServiceDelivery>
# 		<ResponseTimestamp>2024-10-21T21:13:13.055691831+02:00</ResponseTimestamp>
# 		<ProducerRef>ENT</ProducerRef>
# 		<EstimatedTimetableDelivery version="2.0">
# 			<ResponseTimestamp>2024-10-21T21:13:13.055693468+02:00</ResponseTimestamp>
# 			<EstimatedJourneyVersionFrame>
# 				<RecordedAtTime>2024-10-21T21:13:13.05569244+02:00</RecordedAtTime>
# 				<EstimatedVehicleJourney>
# 					<RecordedAtTime>2024-10-21T18:11:13.890534162+02:00</RecordedAtTime>
# 					<LineRef>FLT:Line:FLY1</LineRef>
# 					<DirectionRef>ToDrammen</DirectionRef>
# 					<FramedVehicleJourneyRef>
# 						<DataFrameRef>2024-10-22</DataFrameRef>
# 						<DatedVehicleJourneyRef>FLT:ServiceJourney:1-2614-3754-20241022</DatedVehicleJourneyRef>
# 					</FramedVehicleJourneyRef>
# 					<VehicleMode>rail</VehicleMode>
# 					<OriginRef>GAR</OriginRef>
# 					<DestinationRef>DRM</DestinationRef>
# 					<OperatorRef>FLT:Operator:507</OperatorRef>
# 					<ProductCategoryRef>Flytoget</ProductCategoryRef>
# 					<ServiceFeatureRef>Unknown</ServiceFeatureRef>
# 					<Monitored>true</Monitored>
# 					<DataSource>FLT</DataSource>
# 					<VehicleRef>3754</VehicleRef>
# 					<EstimatedCalls>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:453</StopPointRef>
# 							<Order>1</Order>
# 							<StopPointName>Gardermoen</StopPointName>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:10:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:10:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:755</StopPointRef>
# 							<Order>2</Order>
# 							<StopPointName>Lillestrøm</StopPointName>
# 							<AimedArrivalTime>2024-10-22T14:21:30+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T14:21:30+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:22:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:22:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:570</StopPointRef>
# 							<Order>3</Order>
# 							<StopPointName>Oslo S</StopPointName>
# 							<AimedArrivalTime>2024-10-22T14:32:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T14:32:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:35:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:35:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:475</StopPointRef>
# 							<Order>4</Order>
# 							<StopPointName>Nationaltheatret</StopPointName>
# 							<AimedArrivalTime>2024-10-22T14:36:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T14:36:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>1</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:37:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:37:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">1</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:239</StopPointRef>
# 							<Order>5</Order>
# 							<StopPointName>Skøyen</StopPointName>
# 							<AimedArrivalTime>2024-10-22T14:40:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T14:40:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>1</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:41:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:41:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">1</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:248</StopPointRef>
# 							<Order>6</Order>
# 							<StopPointName>Lysaker</StopPointName>
# 							<AimedArrivalTime>2024-10-22T14:44:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T14:44:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:45:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:45:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:991</StopPointRef>
# 							<Order>7</Order>
# 							<StopPointName>Sandvika</StopPointName>
# 							<AimedArrivalTime>2024-10-22T14:49:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T14:49:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>1</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:50:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:50:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">1</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:700</StopPointRef>
# 							<Order>8</Order>
# 							<StopPointName>Asker</StopPointName>
# 							<AimedArrivalTime>2024-10-22T14:55:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T14:55:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:55:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:55:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:20</StopPointRef>
# 							<Order>9</Order>
# 							<StopPointName>Drammen</StopPointName>
# 							<AimedArrivalTime>2024-10-22T15:08:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T15:08:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 					</EstimatedCalls>
# 					<IsCompleteStopSequence>true</IsCompleteStopSequence>
# 				</EstimatedVehicleJourney>
# 				<EstimatedVehicleJourney>
# 					<RecordedAtTime>2024-10-21T18:41:11.414549059+02:00</RecordedAtTime>
# 					<LineRef>FLT:Line:FLY2</LineRef>
# 					<DirectionRef>ToDrammen</DirectionRef>
# 					<FramedVehicleJourneyRef>
# 						<DataFrameRef>2024-10-22</DataFrameRef>
# 						<DatedVehicleJourneyRef>FLT:ServiceJourney:1-2614-3934-20241022</DatedVehicleJourneyRef>
# 					</FramedVehicleJourneyRef>
# 					<VehicleMode>rail</VehicleMode>
# 					<OriginRef>GAR</OriginRef>
# 					<DestinationRef>OSL</DestinationRef>
# 					<OperatorRef>FLT:Operator:507</OperatorRef>
# 					<ProductCategoryRef>Flytoget</ProductCategoryRef>
# 					<ServiceFeatureRef>Unknown</ServiceFeatureRef>
# 					<Monitored>true</Monitored>
# 					<DataSource>FLT</DataSource>
# 					<VehicleRef>3934</VehicleRef>
# 					<EstimatedCalls>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:453</StopPointRef>
# 							<Order>1</Order>
# 							<StopPointName>Gardermoen</StopPointName>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:40:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:40:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:569</StopPointRef>
# 							<Order>2</Order>
# 							<StopPointName>Oslo S</StopPointName>
# 							<AimedArrivalTime>2024-10-22T14:59:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T14:59:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>14</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">14</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 					</EstimatedCalls>
# 					<IsCompleteStopSequence>true</IsCompleteStopSequence>
# 				</EstimatedVehicleJourney>
# 				<EstimatedVehicleJourney>
# 					<RecordedAtTime>2024-10-21T20:50:44.873471149+02:00</RecordedAtTime>
# 					<LineRef>FLT:Line:FLY2</LineRef>
# 					<DirectionRef>ToGardermoen</DirectionRef>
# 					<FramedVehicleJourneyRef>
# 						<DataFrameRef>2024-10-22</DataFrameRef>
# 						<DatedVehicleJourneyRef>FLT:ServiceJourney:1-2614-3573-20241022</DatedVehicleJourneyRef>
# 					</FramedVehicleJourneyRef>
# 					<VehicleMode>rail</VehicleMode>
# 					<OriginRef>STB</OriginRef>
# 					<DestinationRef>GAR</DestinationRef>
# 					<OperatorRef>FLT:Operator:507</OperatorRef>
# 					<ProductCategoryRef>Flytoget</ProductCategoryRef>
# 					<ServiceFeatureRef>Unknown</ServiceFeatureRef>
# 					<Monitored>true</Monitored>
# 					<DataSource>FLT</DataSource>
# 					<VehicleRef>3573</VehicleRef>
# 					<EstimatedCalls>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:1150</StopPointRef>
# 							<Order>1</Order>
# 							<StopPointName>Stabekk</StopPointName>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T16:53:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T16:53:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:246</StopPointRef>
# 							<Order>2</Order>
# 							<StopPointName>Lysaker</StopPointName>
# 							<AimedArrivalTime>2024-10-22T16:56:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T16:56:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>4</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T16:57:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T16:57:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">4</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:236</StopPointRef>
# 							<Order>3</Order>
# 							<StopPointName>Skøyen</StopPointName>
# 							<AimedArrivalTime>2024-10-22T16:59:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T16:59:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>4</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T17:00:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T17:00:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">4</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:477</StopPointRef>
# 							<Order>4</Order>
# 							<StopPointName>Nationaltheatret</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:03:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:03:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T17:04:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T17:04:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:557</StopPointRef>
# 							<Order>5</Order>
# 							<StopPointName>Oslo S</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:07:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:07:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>13</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T17:10:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T17:10:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">13</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:447</StopPointRef>
# 							<Order>6</Order>
# 							<StopPointName>Gardermoen</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:29:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:29:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 					</EstimatedCalls>
# 					<IsCompleteStopSequence>true</IsCompleteStopSequence>
# 				</EstimatedVehicleJourney>
# 				<EstimatedVehicleJourney>
# 					<RecordedAtTime>2024-10-21T18:30:32.746273987+02:00</RecordedAtTime>
# 					<LineRef>FLT:Line:FLY2</LineRef>
# 					<DirectionRef>ToGardermoen</DirectionRef>
# 					<FramedVehicleJourneyRef>
# 						<DataFrameRef>2024-10-22</DataFrameRef>
# 						<DatedVehicleJourneyRef>FLT:ServiceJourney:1-2614-3935-20241022</DatedVehicleJourneyRef>
# 					</FramedVehicleJourneyRef>
# 					<VehicleMode>rail</VehicleMode>
# 					<OriginRef>OSL</OriginRef>
# 					<DestinationRef>GAR</DestinationRef>
# 					<OperatorRef>FLT:Operator:507</OperatorRef>
# 					<ProductCategoryRef>Flytoget</ProductCategoryRef>
# 					<ServiceFeatureRef>Unknown</ServiceFeatureRef>
# 					<Monitored>true</Monitored>
# 					<DataSource>FLT</DataSource>
# 					<VehicleRef>3935</VehicleRef>
# 					<EstimatedCalls>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:569</StopPointRef>
# 							<Order>1</Order>
# 							<StopPointName>Oslo S</StopPointName>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>14</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:30:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:30:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">14</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:447</StopPointRef>
# 							<Order>2</Order>
# 							<StopPointName>Gardermoen</StopPointName>
# 							<AimedArrivalTime>2024-10-22T14:49:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T14:49:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 					</EstimatedCalls>
# 					<IsCompleteStopSequence>true</IsCompleteStopSequence>
# 				</EstimatedVehicleJourney>
# 				<EstimatedVehicleJourney>
# 					<RecordedAtTime>2024-10-21T18:21:10.500311472+02:00</RecordedAtTime>
# 					<LineRef>FLT:Line:FLY2</LineRef>
# 					<DirectionRef>ToDrammen</DirectionRef>
# 					<FramedVehicleJourneyRef>
# 						<DataFrameRef>2024-10-22</DataFrameRef>
# 						<DatedVehicleJourneyRef>FLT:ServiceJourney:1-2614-3932-20241022</DatedVehicleJourneyRef>
# 					</FramedVehicleJourneyRef>
# 					<VehicleMode>rail</VehicleMode>
# 					<OriginRef>GAR</OriginRef>
# 					<DestinationRef>OSL</DestinationRef>
# 					<OperatorRef>FLT:Operator:507</OperatorRef>
# 					<ProductCategoryRef>Flytoget</ProductCategoryRef>
# 					<ServiceFeatureRef>Unknown</ServiceFeatureRef>
# 					<Monitored>true</Monitored>
# 					<DataSource>FLT</DataSource>
# 					<VehicleRef>3932</VehicleRef>
# 					<EstimatedCalls>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:453</StopPointRef>
# 							<Order>1</Order>
# 							<StopPointName>Gardermoen</StopPointName>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:20:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:20:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:569</StopPointRef>
# 							<Order>2</Order>
# 							<StopPointName>Oslo S</StopPointName>
# 							<AimedArrivalTime>2024-10-22T14:55:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T14:55:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>14</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">14</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 					</EstimatedCalls>
# 					<IsCompleteStopSequence>true</IsCompleteStopSequence>
# 				</EstimatedVehicleJourney>
# 				<EstimatedVehicleJourney>
# 					<RecordedAtTime>2024-10-21T18:30:32.745357219+02:00</RecordedAtTime>
# 					<LineRef>FLT:Line:FLY1</LineRef>
# 					<DirectionRef>ToDrammen</DirectionRef>
# 					<FramedVehicleJourneyRef>
# 						<DataFrameRef>2024-10-22</DataFrameRef>
# 						<DatedVehicleJourneyRef>FLT:ServiceJourney:1-2614-3756-20241022</DatedVehicleJourneyRef>
# 					</FramedVehicleJourneyRef>
# 					<VehicleMode>rail</VehicleMode>
# 					<OriginRef>GAR</OriginRef>
# 					<DestinationRef>DRM</DestinationRef>
# 					<OperatorRef>FLT:Operator:507</OperatorRef>
# 					<ProductCategoryRef>Flytoget</ProductCategoryRef>
# 					<ServiceFeatureRef>Unknown</ServiceFeatureRef>
# 					<Monitored>true</Monitored>
# 					<DataSource>FLT</DataSource>
# 					<VehicleRef>3756</VehicleRef>
# 					<EstimatedCalls>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:453</StopPointRef>
# 							<Order>1</Order>
# 							<StopPointName>Gardermoen</StopPointName>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:30:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:30:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:755</StopPointRef>
# 							<Order>2</Order>
# 							<StopPointName>Lillestrøm</StopPointName>
# 							<AimedArrivalTime>2024-10-22T14:41:30+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T14:41:30+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:42:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:42:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:570</StopPointRef>
# 							<Order>3</Order>
# 							<StopPointName>Oslo S</StopPointName>
# 							<AimedArrivalTime>2024-10-22T14:52:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T14:52:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:55:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:55:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:475</StopPointRef>
# 							<Order>4</Order>
# 							<StopPointName>Nationaltheatret</StopPointName>
# 							<AimedArrivalTime>2024-10-22T14:56:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T14:56:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>1</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:57:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:57:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">1</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:239</StopPointRef>
# 							<Order>5</Order>
# 							<StopPointName>Skøyen</StopPointName>
# 							<AimedArrivalTime>2024-10-22T15:00:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T15:00:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>1</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T15:01:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T15:01:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">1</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:248</StopPointRef>
# 							<Order>6</Order>
# 							<StopPointName>Lysaker</StopPointName>
# 							<AimedArrivalTime>2024-10-22T15:04:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T15:04:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T15:05:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T15:05:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:991</StopPointRef>
# 							<Order>7</Order>
# 							<StopPointName>Sandvika</StopPointName>
# 							<AimedArrivalTime>2024-10-22T15:09:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T15:09:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>1</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T15:10:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T15:10:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">1</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:700</StopPointRef>
# 							<Order>8</Order>
# 							<StopPointName>Asker</StopPointName>
# 							<AimedArrivalTime>2024-10-22T15:15:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T15:15:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T15:15:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T15:15:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:20</StopPointRef>
# 							<Order>9</Order>
# 							<StopPointName>Drammen</StopPointName>
# 							<AimedArrivalTime>2024-10-22T15:28:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T15:28:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 					</EstimatedCalls>
# 					<IsCompleteStopSequence>true</IsCompleteStopSequence>
# 				</EstimatedVehicleJourney>
# 				<EstimatedVehicleJourney>
# 					<RecordedAtTime>2024-10-21T20:31:10.540089089+02:00</RecordedAtTime>
# 					<LineRef>FLT:Line:FLY1</LineRef>
# 					<DirectionRef>ToDrammen</DirectionRef>
# 					<FramedVehicleJourneyRef>
# 						<DataFrameRef>2024-10-22</DataFrameRef>
# 						<DatedVehicleJourneyRef>FLT:ServiceJourney:1-2614-3768-20241022</DatedVehicleJourneyRef>
# 					</FramedVehicleJourneyRef>
# 					<VehicleMode>rail</VehicleMode>
# 					<OriginRef>GAR</OriginRef>
# 					<DestinationRef>DRM</DestinationRef>
# 					<OperatorRef>FLT:Operator:507</OperatorRef>
# 					<ProductCategoryRef>Flytoget</ProductCategoryRef>
# 					<ServiceFeatureRef>Unknown</ServiceFeatureRef>
# 					<Monitored>true</Monitored>
# 					<DataSource>FLT</DataSource>
# 					<VehicleRef>3768</VehicleRef>
# 					<EstimatedCalls>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:453</StopPointRef>
# 							<Order>1</Order>
# 							<StopPointName>Gardermoen</StopPointName>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T16:30:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T16:30:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:755</StopPointRef>
# 							<Order>2</Order>
# 							<StopPointName>Lillestrøm</StopPointName>
# 							<AimedArrivalTime>2024-10-22T16:41:30+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T16:41:30+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T16:42:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T16:42:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:570</StopPointRef>
# 							<Order>3</Order>
# 							<StopPointName>Oslo S</StopPointName>
# 							<AimedArrivalTime>2024-10-22T16:52:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T16:52:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T16:55:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T16:55:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:475</StopPointRef>
# 							<Order>4</Order>
# 							<StopPointName>Nationaltheatret</StopPointName>
# 							<AimedArrivalTime>2024-10-22T16:56:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T16:56:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>1</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T16:57:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T16:57:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">1</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:239</StopPointRef>
# 							<Order>5</Order>
# 							<StopPointName>Skøyen</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:00:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:00:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>1</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T17:01:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T17:01:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">1</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:248</StopPointRef>
# 							<Order>6</Order>
# 							<StopPointName>Lysaker</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:04:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:04:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T17:05:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T17:05:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:991</StopPointRef>
# 							<Order>7</Order>
# 							<StopPointName>Sandvika</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:09:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:09:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>1</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T17:10:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T17:10:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">1</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:700</StopPointRef>
# 							<Order>8</Order>
# 							<StopPointName>Asker</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:15:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:15:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T17:15:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T17:15:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:20</StopPointRef>
# 							<Order>9</Order>
# 							<StopPointName>Drammen</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:28:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:28:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 					</EstimatedCalls>
# 					<IsCompleteStopSequence>true</IsCompleteStopSequence>
# 				</EstimatedVehicleJourney>
# 				<EstimatedVehicleJourney>
# 					<RecordedAtTime>2024-10-21T20:41:07.639327452+02:00</RecordedAtTime>
# 					<LineRef>FLT:Line:FLY2</LineRef>
# 					<DirectionRef>ToDrammen</DirectionRef>
# 					<FramedVehicleJourneyRef>
# 						<DataFrameRef>2024-10-21</DataFrameRef>
# 						<DatedVehicleJourneyRef>FLT:ServiceJourney:1-2614-3598-20241021</DatedVehicleJourneyRef>
# 					</FramedVehicleJourneyRef>
# 					<VehicleMode>rail</VehicleMode>
# 					<OriginRef>GAR</OriginRef>
# 					<DestinationRef>STB</DestinationRef>
# 					<OperatorRef>FLT:Operator:507</OperatorRef>
# 					<ProductCategoryRef>Flytoget</ProductCategoryRef>
# 					<ServiceFeatureRef>Passenger</ServiceFeatureRef>
# 					<Monitored>true</Monitored>
# 					<DataSource>FLT</DataSource>
# 					<VehicleRef>3598</VehicleRef>
# 					<EstimatedCalls>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:453</StopPointRef>
# 							<Order>1</Order>
# 							<StopPointName>Gardermoen</StopPointName>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-21T21:40:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-21T21:40:00+02:00</ExpectedDepartureTime>
# 							<DepartureStatus>onTime</DepartureStatus>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:570</StopPointRef>
# 							<Order>2</Order>
# 							<StopPointName>Oslo S</StopPointName>
# 							<AimedArrivalTime>2024-10-21T21:59:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-21T21:59:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>onTime</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-21T22:01:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-21T22:01:00+02:00</ExpectedDepartureTime>
# 							<DepartureStatus>onTime</DepartureStatus>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:478</StopPointRef>
# 							<Order>3</Order>
# 							<StopPointName>Nationaltheatret</StopPointName>
# 							<AimedArrivalTime>2024-10-21T22:02:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-21T22:02:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>onTime</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-21T22:03:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-21T22:03:00+02:00</ExpectedDepartureTime>
# 							<DepartureStatus>onTime</DepartureStatus>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:237</StopPointRef>
# 							<Order>4</Order>
# 							<StopPointName>Skøyen</StopPointName>
# 							<AimedArrivalTime>2024-10-21T22:06:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-21T22:06:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>onTime</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-21T22:07:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-21T22:07:00+02:00</ExpectedDepartureTime>
# 							<DepartureStatus>onTime</DepartureStatus>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:250</StopPointRef>
# 							<Order>5</Order>
# 							<StopPointName>Lysaker</StopPointName>
# 							<AimedArrivalTime>2024-10-21T22:10:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-21T22:10:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>onTime</ArrivalStatus>
# 							<ArrivalPlatformName>1</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-21T22:11:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-21T22:11:00+02:00</ExpectedDepartureTime>
# 							<DepartureStatus>onTime</DepartureStatus>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">1</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:1151</StopPointRef>
# 							<Order>6</Order>
# 							<StopPointName>Stabekk</StopPointName>
# 							<AimedArrivalTime>2024-10-21T22:14:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-21T22:14:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>onTime</ArrivalStatus>
# 							<ArrivalPlatformName>1</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">1</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 					</EstimatedCalls>
# 					<IsCompleteStopSequence>true</IsCompleteStopSequence>
# 				</EstimatedVehicleJourney>
# 				<EstimatedVehicleJourney>
# 					<RecordedAtTime>2024-10-21T21:12:10.510848867+02:00</RecordedAtTime>
# 					<LineRef>FLT:Line:FLY1</LineRef>
# 					<DirectionRef>ToGardermoen</DirectionRef>
# 					<FramedVehicleJourneyRef>
# 						<DataFrameRef>2024-10-21</DataFrameRef>
# 						<DatedVehicleJourneyRef>FLT:ServiceJourney:1-2614-3801-20241021</DatedVehicleJourneyRef>
# 					</FramedVehicleJourneyRef>
# 					<VehicleMode>rail</VehicleMode>
# 					<OriginRef>DRM</OriginRef>
# 					<DestinationRef>GAR</DestinationRef>
# 					<OperatorRef>FLT:Operator:507</OperatorRef>
# 					<ProductCategoryRef>Flytoget</ProductCategoryRef>
# 					<ServiceFeatureRef>Unknown</ServiceFeatureRef>
# 					<Monitored>true</Monitored>
# 					<DataSource>FLT</DataSource>
# 					<VehicleRef>3801</VehicleRef>
# 					<RecordedCalls>
# 						<RecordedCall>
# 							<StopPointRef>NSR:Quay:20</StopPointRef>
# 							<Order>1</Order>
# 							<StopPointName>Drammen</StopPointName>
# 							<AimedDepartureTime>2024-10-21T20:39:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-21T20:39:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName>3</DeparturePlatformName>
# 						</RecordedCall>
# 						<RecordedCall>
# 							<StopPointRef>NSR:Quay:700</StopPointRef>
# 							<Order>2</Order>
# 							<StopPointName>Asker</StopPointName>
# 							<AimedArrivalTime>2024-10-21T20:52:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-21T20:52:00+02:00</ExpectedArrivalTime>
# 							<AimedDepartureTime>2024-10-21T20:52:00+02:00</AimedDepartureTime>
# 							<DeparturePlatformName>2</DeparturePlatformName>
# 							<ActualDepartureTime>2024-10-21T20:52:42+02:00</ActualDepartureTime>
# 						</RecordedCall>
# 						<RecordedCall>
# 							<StopPointRef>NSR:Quay:993</StopPointRef>
# 							<Order>3</Order>
# 							<StopPointName>Sandvika</StopPointName>
# 							<AimedArrivalTime>2024-10-21T20:58:00+02:00</AimedArrivalTime>
# 							<ActualArrivalTime>2024-10-21T20:59:01+02:00</ActualArrivalTime>
# 							<AimedDepartureTime>2024-10-21T21:00:00+02:00</AimedDepartureTime>
# 							<DeparturePlatformName>4</DeparturePlatformName>
# 							<ActualDepartureTime>2024-10-21T21:00:19+02:00</ActualDepartureTime>
# 						</RecordedCall>
# 						<RecordedCall>
# 							<StopPointRef>NSR:Quay:247</StopPointRef>
# 							<Order>4</Order>
# 							<StopPointName>Lysaker</StopPointName>
# 							<AimedArrivalTime>2024-10-21T21:05:00+02:00</AimedArrivalTime>
# 							<ActualArrivalTime>2024-10-21T21:05:34+02:00</ActualArrivalTime>
# 							<AimedDepartureTime>2024-10-21T21:06:00+02:00</AimedDepartureTime>
# 							<DeparturePlatformName>3</DeparturePlatformName>
# 							<ActualDepartureTime>2024-10-21T21:06:35+02:00</ActualDepartureTime>
# 						</RecordedCall>
# 						<RecordedCall>
# 							<StopPointRef>NSR:Quay:236</StopPointRef>
# 							<Order>5</Order>
# 							<StopPointName>Skøyen</StopPointName>
# 							<AimedArrivalTime>2024-10-21T21:08:00+02:00</AimedArrivalTime>
# 							<ActualArrivalTime>2024-10-21T21:09:10+02:00</ActualArrivalTime>
# 							<AimedDepartureTime>2024-10-21T21:09:00+02:00</AimedDepartureTime>
# 							<DeparturePlatformName>4</DeparturePlatformName>
# 							<ActualDepartureTime>2024-10-21T21:10:09+02:00</ActualDepartureTime>
# 						</RecordedCall>
# 					</RecordedCalls>
# 					<EstimatedCalls>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:476</StopPointRef>
# 							<Order>6</Order>
# 							<StopPointName>Nationaltheatret</StopPointName>
# 							<AimedArrivalTime>2024-10-21T21:12:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-21T21:12:05+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>delayed</ArrivalStatus>
# 							<ArrivalPlatformName>4</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-21T21:13:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-21T21:13:00+02:00</ExpectedDepartureTime>
# 							<DepartureStatus>onTime</DepartureStatus>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">4</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:557</StopPointRef>
# 							<Order>7</Order>
# ...
# 					<ServiceFeatureRef>Unknown</ServiceFeatureRef>
# 					<Monitored>true</Monitored>
# 					<DataSource>FLT</DataSource>
# 					<VehicleRef>3770</VehicleRef>
# 					<EstimatedCalls>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:453</StopPointRef>
# 							<Order>1</Order>
# 							<StopPointName>Gardermoen</StopPointName>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T16:50:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T16:50:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:755</StopPointRef>
# 							<Order>2</Order>
# 							<StopPointName>Lillestrøm</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:01:30+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:01:30+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T17:02:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T17:02:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:570</StopPointRef>
# 							<Order>3</Order>
# 							<StopPointName>Oslo S</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:12:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:12:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T17:15:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T17:15:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:478</StopPointRef>
# 							<Order>4</Order>
# 							<StopPointName>Nationaltheatret</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:16:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:16:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T17:17:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T17:17:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:239</StopPointRef>
# 							<Order>5</Order>
# 							<StopPointName>Skøyen</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:20:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:20:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>1</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T17:21:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T17:21:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">1</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:248</StopPointRef>
# 							<Order>6</Order>
# 							<StopPointName>Lysaker</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:24:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:24:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T17:25:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T17:25:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:991</StopPointRef>
# 							<Order>7</Order>
# 							<StopPointName>Sandvika</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:29:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:29:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>1</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T17:30:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T17:30:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">1</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:700</StopPointRef>
# 							<Order>8</Order>
# 							<StopPointName>Asker</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:35:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:35:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T17:35:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T17:35:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:20</StopPointRef>
# 							<Order>9</Order>
# 							<StopPointName>Drammen</StopPointName>
# 							<AimedArrivalTime>2024-10-22T17:48:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T17:48:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 					</EstimatedCalls>
# 					<IsCompleteStopSequence>true</IsCompleteStopSequence>
# 				</EstimatedVehicleJourney>
# 				<EstimatedVehicleJourney>
# 					<RecordedAtTime>2024-10-21T19:12:26.704752751+02:00</RecordedAtTime>
# 					<LineRef>FLT:Line:FLY1</LineRef>
# 					<DirectionRef>ToGardermoen</DirectionRef>
# 					<FramedVehicleJourneyRef>
# 						<DataFrameRef>2024-10-22</DataFrameRef>
# 						<DatedVehicleJourneyRef>FLT:ServiceJourney:1-2614-3767-20241022</DatedVehicleJourneyRef>
# 					</FramedVehicleJourneyRef>
# 					<VehicleMode>rail</VehicleMode>
# 					<OriginRef>DRM</OriginRef>
# 					<DestinationRef>GAR</DestinationRef>
# 					<OperatorRef>FLT:Operator:507</OperatorRef>
# 					<ProductCategoryRef>Flytoget</ProductCategoryRef>
# 					<ServiceFeatureRef>Unknown</ServiceFeatureRef>
# 					<Monitored>true</Monitored>
# 					<DataSource>FLT</DataSource>
# 					<VehicleRef>3767</VehicleRef>
# 					<EstimatedCalls>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:20</StopPointRef>
# 							<Order>1</Order>
# 							<StopPointName>Drammen</StopPointName>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T14:59:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T14:59:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:700</StopPointRef>
# 							<Order>2</Order>
# 							<StopPointName>Asker</StopPointName>
# 							<AimedArrivalTime>2024-10-22T15:12:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T15:12:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T15:12:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T15:12:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:993</StopPointRef>
# 							<Order>3</Order>
# 							<StopPointName>Sandvika</StopPointName>
# 							<AimedArrivalTime>2024-10-22T15:18:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T15:18:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>4</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T15:20:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T15:20:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">4</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:247</StopPointRef>
# 							<Order>4</Order>
# 							<StopPointName>Lysaker</StopPointName>
# 							<AimedArrivalTime>2024-10-22T15:25:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T15:25:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T15:26:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T15:26:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:236</StopPointRef>
# 							<Order>5</Order>
# 							<StopPointName>Skøyen</StopPointName>
# 							<AimedArrivalTime>2024-10-22T15:28:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T15:28:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>4</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T15:29:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T15:29:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">4</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:477</StopPointRef>
# 							<Order>6</Order>
# 							<StopPointName>Nationaltheatret</StopPointName>
# 							<AimedArrivalTime>2024-10-22T15:32:10+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T15:32:10+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T15:33:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T15:33:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:557</StopPointRef>
# 							<Order>7</Order>
# 							<StopPointName>Oslo S</StopPointName>
# 							<AimedArrivalTime>2024-10-22T15:36:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T15:36:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>13</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T15:40:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T15:40:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">13</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:761</StopPointRef>
# 							<Order>8</Order>
# 							<StopPointName>Lillestrøm</StopPointName>
# 							<AimedArrivalTime>2024-10-22T15:49:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T15:49:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>3</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>noAlighting</ArrivalBoardingActivity>
# 							<AimedDepartureTime>2024-10-22T15:50:00+02:00</AimedDepartureTime>
# 							<ExpectedDepartureTime>2024-10-22T15:50:00+02:00</ExpectedDepartureTime>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">3</DeparturePlatformName>
# 							<DepartureBoardingActivity>boarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 						<EstimatedCall>
# 							<StopPointRef>NSR:Quay:447</StopPointRef>
# 							<Order>9</Order>
# 							<StopPointName>Gardermoen</StopPointName>
# 							<AimedArrivalTime>2024-10-22T16:02:00+02:00</AimedArrivalTime>
# 							<ExpectedArrivalTime>2024-10-22T16:02:00+02:00</ExpectedArrivalTime>
# 							<ArrivalStatus>arrived</ArrivalStatus>
# 							<ArrivalPlatformName>2</ArrivalPlatformName>
# 							<ArrivalBoardingActivity>alighting</ArrivalBoardingActivity>
# 							<DeparturePlatformName xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:type="DefaultedTextStructure">2</DeparturePlatformName>
# 							<DepartureBoardingActivity>noBoarding</DepartureBoardingActivity>
# 						</EstimatedCall>
# 					</EstimatedCalls>
# 					<IsCompleteStopSequence>true</IsCompleteStopSequence>
# 				</EstimatedVehicleJourney>
# 			</EstimatedJourneyVersionFrame>
# 		</EstimatedTimetableDelivery>
# 	</ServiceDelivery>
# </Siri>

# %%
# Define the namespace used in the XML
namespace = {'siri': 'http://www.siri.org.uk/siri'}

# Prepare lists to store data for each EstimatedVehicleJourney and EstimatedCall
rows = []

# Iterate through EstimatedVehicleJourney elements
for journey in root.findall('.//siri:EstimatedVehicleJourney', namespace):
    # Extract common fields for each vehicle journey
    vehicle_data = {
        'RecordedAtTime': journey.find('siri:RecordedAtTime', namespace).text,
        'DirectionRef': journey.find('siri:DirectionRef', namespace).text,
        'OriginRef': journey.find('siri:OriginRef', namespace).text,
        'DestinationRef': journey.find('siri:DestinationRef', namespace).text,
        'VehicleRef': journey.find('siri:VehicleRef', namespace).text,
        'OperatorRef': journey.find('siri:OperatorRef', namespace).text
    }
    
    # Iterate through the EstimatedCall elements for each journey
    for call in journey.findall('siri:EstimatedCalls/siri:EstimatedCall', namespace):
        aimed_departure_time = call.find('siri:AimedDepartureTime', namespace)
        aimed_departure_time_value = aimed_departure_time.text if aimed_departure_time is not None else None
        
        # Prepare call data
        call_data = {
            'StopPointName': call.find('siri:StopPointName', namespace).text,
            'ArrivalStatus': call.find('siri:ArrivalStatus', namespace).text,
            'AimedDepartureTime': aimed_departure_time_value,
            'ExpectedDepartureTime': call.find('siri:ExpectedDepartureTime', namespace).text if call.find('siri:ExpectedDepartureTime', namespace) is not None else None,
            'Order': call.find('siri:Order', namespace).text if call.find('siri:Order', namespace) is not None else None,
        }

        # Combine vehicle data with call data into one dictionary
        combined_data = {**vehicle_data, **call_data}
        
        # Add the combined data to the list of rows
        rows.append(combined_data)

# Create a DataFrame from the rows
df = pd.DataFrame(rows)

# Display the DataFrame
df.head()
# Out:
#                         RecordedAtTime DirectionRef OriginRef DestinationRef  \
# 0  2024-10-21T18:11:13.890534162+02:00    ToDrammen       GAR            DRM
# 1  2024-10-21T18:11:13.890534162+02:00    ToDrammen       GAR            DRM
# 2  2024-10-21T18:11:13.890534162+02:00    ToDrammen       GAR            DRM
# 3  2024-10-21T18:11:13.890534162+02:00    ToDrammen       GAR            DRM
# 4  2024-10-21T18:11:13.890534162+02:00    ToDrammen       GAR            DRM
#
#   VehicleRef       OperatorRef     StopPointName ArrivalStatus  \
# 0       3754  FLT:Operator:507        Gardermoen       arrived
# 1       3754  FLT:Operator:507        Lillestrøm       arrived
# 2       3754  FLT:Operator:507            Oslo S       arrived
# 3       3754  FLT:Operator:507  Nationaltheatret       arrived
# 4       3754  FLT:Operator:507            Skøyen       arrived
#
#           AimedDepartureTime      ExpectedDepartureTime Order
# 0  2024-10-22T14:10:00+02:00  2024-10-22T14:10:00+02:00     1
# 1  2024-10-22T14:22:00+02:00  2024-10-22T14:22:00+02:00     2
# 2  2024-10-22T14:35:00+02:00  2024-10-22T14:35:00+02:00     3
# 3  2024-10-22T14:37:00+02:00  2024-10-22T14:37:00+02:00     4
# 4  2024-10-22T14:41:00+02:00  2024-10-22T14:41:00+02:00     5

# %%
df['RecordedAtTime'] = pd.to_datetime(df['RecordedAtTime'])
df['AimedDepartureTime'] = pd.to_datetime(df['AimedDepartureTime'])
df['ExpectedDepartureTime'] = pd.to_datetime(df['ExpectedDepartureTime'])

df['aimed_dep_time'] = df['AimedDepartureTime'].dt.time
df['expected_dep_time'] = df['ExpectedDepartureTime'].dt.time
df['date'] = df['ExpectedDepartureTime'].dt.date
df['month'] = df['ExpectedDepartureTime'].dt.month_name()
df['year'] = df['ExpectedDepartureTime'].dt.year
df['recorded_at_time'] = df['RecordedAtTime'].dt.strftime('%Y-%m-%d %H:%M:%S')

cols = ['recorded_at_time', 'DirectionRef', 'OriginRef', 'DestinationRef', 'VehicleRef', 
         'OperatorRef', 'StopPointName', 'ArrivalStatus', 'Order', 'aimed_dep_time',
         'expected_dep_time', 'month', 'year', 'date'
       ]
df = df[cols] 

df.rename(columns={'Order': 'order_of_stops'}, inplace=True)


df.head()
# Out:
#       recorded_at_time DirectionRef OriginRef DestinationRef VehicleRef  \
# 0  2024-10-21 18:11:13    ToDrammen       GAR            DRM       3754
# 1  2024-10-21 18:11:13    ToDrammen       GAR            DRM       3754
# 2  2024-10-21 18:11:13    ToDrammen       GAR            DRM       3754
# 3  2024-10-21 18:11:13    ToDrammen       GAR            DRM       3754
# 4  2024-10-21 18:11:13    ToDrammen       GAR            DRM       3754
#
#         OperatorRef     StopPointName ArrivalStatus order_of_stops  \
# 0  FLT:Operator:507        Gardermoen       arrived              1
# 1  FLT:Operator:507        Lillestrøm       arrived              2
# 2  FLT:Operator:507            Oslo S       arrived              3
# 3  FLT:Operator:507  Nationaltheatret       arrived              4
# 4  FLT:Operator:507            Skøyen       arrived              5
#
#   aimed_dep_time expected_dep_time    month    year        date
# 0       14:10:00          14:10:00  October  2024.0  2024-10-22
# 1       14:22:00          14:22:00  October  2024.0  2024-10-22
# 2       14:35:00          14:35:00  October  2024.0  2024-10-22
# 3       14:37:00          14:37:00  October  2024.0  2024-10-22
# 4       14:41:00          14:41:00  October  2024.0  2024-10-22
